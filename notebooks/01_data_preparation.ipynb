# %% [markdown]
# # 01 - Data Preparation
# This notebook generates a synthetic aerospace supply-chain dataset and gives a quick sanity check.

# %% [markdown]
# ## Step 1: Generate data
# Create a reproducible synthetic dataset and preview a few rows.

# %%
from pathlib import Path
import sys

# Ensure project root (folder containing src/) is importable in notebook sessions.
project_root = Path.cwd().resolve()
while not (project_root / "src").exists() and project_root != project_root.parent:
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.data_generation import GenerationConfig, generate_supply_chain_data

config = GenerationConfig(num_suppliers=25, num_components=8, seed=42)
df = generate_supply_chain_data(config)
df.head()
# Out:
#   supplier_id                   component     unit_cost  fixed_penalty  \
# 0         S01         Merlin 1D turbopump  14592.394498    3326.494130
# 1         S01             Raptor injector   2111.118328     786.300070
# 2         S01  Starship heat shield tiles  15765.514122    1386.993237
# 3         S01    Avionics flight computer  13029.816876     731.228593
# 4         S01   Cryogenic propellant tank  18950.783924    1088.970046
#
#    lead_time_days  capacity  reliability_score  historical_mean_delay  \
# 0       16.901475       108           0.884377               1.637940
# 1       10.000815       135           0.884377               4.319359
# 2       15.490173       138           0.884377               2.411314
# 3        9.883737        68           0.884377               5.269726
# 4        9.127930       145           0.884377               3.685509
#
#    historical_delay_std  distance_km transportation_mode  inventory_level  \
# ...

# %% [markdown]
# ## Step 2: Quick check
# Review ranges, including telemetry anomaly and carbon columns.

# %%
df.describe(include='all').transpose().head(20)
# Out:
#                        count unique                  top freq          mean  \
# supplier_id              200     25                  S01    8           NaN
# component                200      8  Merlin 1D turbopump   25           NaN
# unit_cost              200.0    NaN                  NaN  NaN  11864.128401
# fixed_penalty          200.0    NaN                  NaN  NaN   2181.074231
# lead_time_days         200.0    NaN                  NaN  NaN     10.327796
# capacity               200.0    NaN                  NaN  NaN        98.615
# reliability_score      200.0    NaN                  NaN  NaN      0.853685
# historical_mean_delay  200.0    NaN                  NaN  NaN      4.499396
# historical_delay_std   200.0    NaN                  NaN  NaN      1.750183
# distance_km            200.0    NaN                  NaN  NaN   5803.571835
# transportation_mode      200      3                 road   95           NaN
# ...

# %% [markdown]
# ## Step 3: Save dataset
# Write the dataset to ../data for the next notebooks.

# %%
df.to_csv('../data/supply_chain_dataset.csv', index=False)
print('Saved dataset to ../data/supply_chain_dataset.csv')
# Out:
# Saved dataset to ../data/supply_chain_dataset.csv
